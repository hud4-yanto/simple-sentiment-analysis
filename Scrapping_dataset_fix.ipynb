# %% [markdown]
# # Scrapping Dataset Google Play Store

# %% [markdown]
# ## Import Library

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort, reviews_all

import pandas as pd  # Pandas untuk manipulasi dan analisis data
pd.options.mode.chained_assignment = None  # Menonaktifkan peringatan chaining
import numpy as np  # NumPy untuk komputasi numerik
seed = 0
np.random.seed(seed)  # Mengatur seed untuk reproduktibilitas
import datetime as dt  # Manipulasi data waktu dan tanggal

# %% [markdown]
# ## Scrapping Dataset

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews_all, Sort

hasilscrap,_ = reviews(
    'com.telkomsel.telkomselcm',          # ID aplikasi

    lang='id',             # Bahasa ulasan (default: 'en')
    country='id',          # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT, # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=10000
)

# %%
# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(hasilscrap)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
# Menampilkan DataFrame app_reviews_df
app_reviews_df
# Out:
#                                   reviewId          userName  \
# 0     71fd1e8e-029c-4425-b2f6-23c774b7ed3e   Pengguna Google
# 1     2c8e0f86-7cee-424d-a7ee-1bbf832a8de5   Pengguna Google
# 2     7554336f-d8fa-4bca-955b-e7ee03e0de8c   Pengguna Google
# 3     998ddb17-949d-49af-8125-536f632db582   Pengguna Google
# 4     ee1e41d4-ea1f-4096-b0f3-884b74274b6e   Pengguna Google
# ...                                    ...               ...
# 9995  6110d693-71b1-40ea-9c95-6ae8b7334584      Rara Cantika
# 9996  b5645874-2fa3-4a58-a160-d29055c56a1f        Ermanda 79
# 9997  97cae27b-81c0-4bce-bef4-0ff1b4e60e07     Willy Budiman
# 9998  dbfef2d9-1734-4236-9a35-433c90133ae0  Sonali Gurusinga
# 9999  491b8dba-bf0e-4f4c-9c39-f762c51e9ca4     Dimas Galilea
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# 3     https://play-lh.googleusercontent.com/EGemoI2N...
# 4     https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                 ...
# 9995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9997  https://play-lh.googleusercontent.com/a-/ALV-U...
# 9998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 9999  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                 content  score  thumbsUpCount  \
# 0     Sudah banyak yg ngeluh ini aplikasi lemot para...      1              2
# 1     tidak perlu munculkan popup utk membeli paket,...      1           1904
# 2     terlalu banyak fitur gak berguna di MyTelkomse...      1           2414
# 3     aplikasi my telkomsel memang yg paling busuk d...      1            409
# 4     Harga ELIT jaringan SULIT. KUOTA SERBA MAHAL N...      1           4984
# ...                                                 ...    ...            ...
# 9995  Bingung setelah update jadi lebih lemot, kalo ...      1              0
# 9996  Setiap ada misi daily chek in selalu saya ikut...      1              0
# 9997  Aplikasinya ini tambah berat, tambah lemot, in...      1              9
# 9998  Apk yg bagus, tpi setelah di update malah gk b...      2              0
# 9999  akhir akhir ini aplikasi lambat dan tidak berf...      2              0
#
#      reviewCreatedVersion                  at  \
# 0                   8.7.0 2025-04-30 15:18:54
# 1                   8.7.0 2025-05-04 01:01:07
# 2                   8.7.0 2025-05-01 00:42:26
# 3                   8.7.0 2025-05-14 23:28:30
# 4                   8.7.0 2025-04-24 16:40:24
# ...                   ...                 ...
# 9995                 None 2024-11-24 21:44:57
# 9996                8.2.0 2025-01-01 10:32:01
# 9997                8.4.2 2024-12-13 07:11:15
# 9998                 None 2024-11-29 23:58:51
# 9999                8.7.0 2025-04-19 05:06:53
#
#                                            replyContent           repliedAt  \
# 0                                                  None                 NaT
# 1     Makasih ya Kak Masmo untuk masukannya, berharg... 2020-09-22 11:24:48
# 2     Hai Kak Fahri. Maaf bikin gak nyaman, apabila ... 2025-05-01 01:28:51
# 3     Hai Kak Abdillah. Mohon maaf untuk ketidaknyam... 2025-05-15 05:44:09
# 4                                                  None                 NaT
# ...                                                 ...                 ...
# 9995  Hai Kak Cantika. Mohon maaf untuk ketidaknyama... 2024-11-25 00:37:49
# 9996  Hai, Kak Ermanda. Maaf ya. Mengenai keluhan ga... 2022-11-29 23:39:22
# 9997  Hai Kak Willy. Mohon maaf untuk ketidaknyamana... 2024-12-13 08:56:56
# 9998                                               None                 NaT
# 9999  Hai Kak Dimas, Mohon maaf untuk ketidaknyamana... 2025-04-19 13:38:53
#
#      appVersion
# 0         8.7.0
# 1         8.7.0
# 2         8.7.0
# 3         8.7.0
# 4         8.7.0
# ...         ...
# 9995       None
# 9996      8.2.0
# 9997      8.4.2
# 9998       None
# 9999      8.7.0
#
# [10000 rows x 11 columns]

# %%
# Menampilkan informasi tentang DataFrame app_reviews_df
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              10000 non-null  object
#  1   userName              10000 non-null  object
#  2   userImage             10000 non-null  object
#  3   content               10000 non-null  object
#  4   score                 10000 non-null  int64
#  5   thumbsUpCount         10000 non-null  int64
#  6   reviewCreatedVersion  9881 non-null   object
#  7   at                    10000 non-null  datetime64[ns]
#  8   replyContent          6196 non-null   object
#  9   repliedAt             6196 non-null   datetime64[ns]
#  10  appVersion            9881 non-null   object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 859.5+ KB

# %% [markdown]
# ## Data Cleaning

# %%
# Membuat DataFrame baru (clean_df) dengan menghapus baris yang memiliki nilai yang hilang (NaN) dari app_reviews_df
clean_df = app_reviews_df.dropna()

# %%
# Menghapus baris duplikat dari DataFrame clean_df
clean_df = clean_df.drop_duplicates()

# Menghitung jumlah baris dan kolom dalam DataFrame clean_df setelah menghapus duplikat
jumlah_ulasan_setelah_hapus_duplikat, jumlah_kolom_setelah_hapus_duplikat = clean_df.shape
clean_df.shape
# Out:
# (6128, 11)

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6128 entries, 1 to 9999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              6128 non-null   object
#  1   userName              6128 non-null   object
#  2   userImage             6128 non-null   object
#  3   content               6128 non-null   object
#  4   score                 6128 non-null   int64
#  5   thumbsUpCount         6128 non-null   int64
#  6   reviewCreatedVersion  6128 non-null   object
#  7   at                    6128 non-null   datetime64[ns]
#  8   replyContent          6128 non-null   object
#  9   repliedAt             6128 non-null   datetime64[ns]
#  10  appVersion            6128 non-null   object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 574.5+ KB

# %% [markdown]
# ## Export Data

# %%
# Store subset_df ke csv
clean_df.to_csv('data.csv', index=False)

# %%
pip freeze > requirements.txt
