# %% [markdown]
# # Scrapping Dataset My Telkomsel Google Play Store

# %% [markdown]
# ## Install Library

# %%
# !pip install google-play-scraper

# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort, reviews_all

import pandas as pd  # Pandas untuk manipulasi dan analisis data
pd.options.mode.chained_assignment = None  # Menonaktifkan peringatan chaining
import numpy as np  # NumPy untuk komputasi numerik
seed = 0
np.random.seed(seed)  # Mengatur seed untuk reproduktibilitas
import datetime as dt  # Manipulasi data waktu dan tanggal
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Scrapping Dataset

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews_all, Sort

# Proses scraping mungkin memerlukan beberapa saat tergantung pada jumlah ulasan yang ada.
scrapreview = reviews_all(
    'com.telkomsel.telkomselcm',          # ID aplikasi

    lang='id',             # Bahasa ulasan (default: 'en')
    country='id',          # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT # Urutan ulasan (default: Sort.MOST_RELEVANT)
)

# %%
# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
# Menampilkan DataFrame app_reviews_df
app_reviews_df
# Out:
#                                     reviewId         userName  \
# 0       d6e8fc3f-fb98-46a1-a8e8-b0a94e6d1637  Pengguna Google
# 1       9670192e-5074-442b-91e2-a71925303094  Pengguna Google
# 2       ce590d13-60cc-4f25-8092-e4a3430cf849  Pengguna Google
# 3       3cef90e4-2181-4198-96f6-a258a945d88c  Pengguna Google
# 4       a0b9f48e-bc50-403c-8958-ed95b59ea541  Pengguna Google
# ...                                      ...              ...
# 143995  a4168bb0-1fc5-4225-91cf-dfe560c475f6  Pengguna Google
# 143996  ce28f19c-db51-4af1-8a37-864b70cd5889  Pengguna Google
# 143997  9bd5ca18-51b9-42ab-a63d-2092257621a2  Pengguna Google
# 143998  dfa4acee-8f0d-4998-ad81-4d9c4f7c6215  Pengguna Google
# 143999  d1034df8-aa0d-45d2-9c9d-85ec159c23aa  Pengguna Google
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/EGemoI2N...
# 1       https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
# Menampilkan informasi tentang DataFrame app_reviews_df
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144000 entries, 0 to 143999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              144000 non-null  object
#  1   userName              144000 non-null  object
#  2   userImage             144000 non-null  object
#  3   content               144000 non-null  object
#  4   score                 144000 non-null  int64
#  5   thumbsUpCount         144000 non-null  int64
#  6   reviewCreatedVersion  118938 non-null  object
#  7   at                    144000 non-null  datetime64[ns]
#  8   replyContent          72759 non-null   object
#  9   repliedAt             72759 non-null   datetime64[ns]
#  10  appVersion            118938 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 12.1+ MB

# %% [markdown]
# ## Data Cleaning

# %%
# Membuat DataFrame baru (clean_df) dengan menghapus baris yang memiliki nilai yang hilang (NaN) dari app_reviews_df
clean_df = app_reviews_df.dropna()

# %%
# Menghapus baris duplikat dari DataFrame clean_df
clean_df = clean_df.drop_duplicates()

# Menghitung jumlah baris dan kolom dalam DataFrame clean_df setelah menghapus duplikat
jumlah_ulasan_setelah_hapus_duplikat, jumlah_kolom_setelah_hapus_duplikat = clean_df.shape
clean_df.shape
# Out:
# (59866, 11)

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59866 entries, 1 to 143999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              59866 non-null  object
#  1   userName              59866 non-null  object
#  2   userImage             59866 non-null  object
#  3   content               59866 non-null  object
#  4   score                 59866 non-null  int64
#  5   thumbsUpCount         59866 non-null  int64
#  6   reviewCreatedVersion  59866 non-null  object
#  7   at                    59866 non-null  datetime64[ns]
#  8   replyContent          59866 non-null  object
#  9   repliedAt             59866 non-null  datetime64[ns]
#  10  appVersion            59866 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 5.5+ MB

# %% [markdown]
# ## Data Selection & Export Data

# %%
# Data yang nantinya akan digunakan hanya berjumlah 5000 untuk alasan komputasi
subset_df = clean_df.iloc[0:5000, :]
print(subset_df.shape)
# Out:
# (5000, 11)

# %%
subset_df
# Out:
#                                    reviewId         userName  \
# 1      9670192e-5074-442b-91e2-a71925303094  Pengguna Google
# 2      ce590d13-60cc-4f25-8092-e4a3430cf849  Pengguna Google
# 5      792fa0db-d192-4499-8789-7aa36c3c9607  Pengguna Google
# 6      6763f606-114d-4f01-820a-2184a28ca3d1  Pengguna Google
# 7      3867fbac-0570-4a79-9fa9-d3d37cfd7ceb  Pengguna Google
# ...                                     ...              ...
# 12278  9f9213a7-8264-434e-a5f6-729fd3f03e6f  Pengguna Google
# 12281  68a2340f-f49a-4dd6-a729-4da1a7f4cddb  Pengguna Google
# 12282  a74d2d58-dcda-481f-8760-a054c762a3ec  Pengguna Google
# 12283  2c2ea031-659b-41f7-b966-5eba3c9dc6fd  Pengguna Google
# 12290  89aeab3c-b9e4-405f-9770-8880c3cd6669  Pengguna Google
#
#                                                userImage  \
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# 5      https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
# Store subset_df ke csv
subset_df.to_csv('data.csv', index=False)
